# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()

# %%
#pkg = mp.jupyter.open_package()
pkg = mp.jupyter.open_source_package()

pkg.set_sys_path()
from pylib import *

pkg
# Out:
# # Codes for classification of Instructional Programs
# `nces.ed.gov-cip-2020-1.1.1` Last Update: 2023-10-17T20:06:33
#
# _The Classification of Instructional Programs (CIP) is a taxonomic coding scheme of instructional programs._
#
#
# ## Documentation Links
#
# * [Home Page](https://nces.ed.gov/ipeds/cipcode/default.aspx)
# * [Download Page](https://nces.ed.gov/ipeds/cipcode/resources.aspx)
#
#
#
# ## Contacts
#
# * **Wrangler** [Eric Busboom](mailto:eric@civicknowledge.com), [Civic Knowledge](http://civicknowledge.com)
#
# ## Resources
#
# * **[xwalk](notebooks/build.ipynb#xw_df)**. CIP to SOC crosswalk
#
# ## References
# <ul><li> <strong>cip_source</string>, <em>data/CIPCode2020.csv</em>. CIP Codes</li><li> <strong>xwalk_source</string>, <em>data/CIP2020_SOC2018_Crosswalk.xlsx#1</em>. Crosswalk between CIP codes and SOC Occupation codes</li><ul>

# %%
cip_df = pkg.reference('cip_source').dataframe()


t = cip_df[~cip_df.Action.isin(['Deleted','Moved to'])]


def clean_family(v):
    return v[1:].strip('"')

lens = t.CIPCode.apply(clean_family).apply(len)

# Len == 5 is for group categories with descriptions like: 
# Instructional content for this group of programs is defined in codes 12.0401 - 12.0499.
# Useless, so get rid of them. 

t = t[lens!=5]

def clean_code(v):
    v =  v[1:].strip('"')
    if '.' not in v:
        v = v + '.'

    return v.ljust(7, '0') 

cip_df = pd.DataFrame({
    'family': t.CIPFamily.apply(clean_family),
    'code': t.CIPCode.apply(clean_code),
    'title': t.CIPTitle, 
    'desc': t.CIPDefinition
})

cip_df.head()
# Out:
#   family     code                                              title  \
# 0     01  01.0000  AGRICULTURAL/ANIMAL/PLANT/VETERINARY SCIENCE A...
# 2     01  01.0000                              Agriculture, General.
# 4     01  01.0101     Agricultural Business and Management, General.
# 5     01  01.0102     Agribusiness/Agricultural Business Operations.
# 6     01  01.0103                            Agricultural Economics.
#
#                                                 desc
# 0  Instructional programs that focus on agricultu...
# 2  A program that focuses on the general principl...
# 4  A  general program that focuses on modern busi...
# 5  A program that prepares individuals to manage ...
# 6  A program that focuses on the application of e...

# %%
xw_df = pkg.reference('xwalk_source').dataframe()
xw_df.columns = ['cip', 'cip_title', 'soc', 'soc_title']
xw_df
# Out:
#           cip              cip_title      soc  \
# 0     01.0000  Agriculture, General.  19-1011
# 1     01.0000  Agriculture, General.  19-1012
# 2     01.0000  Agriculture, General.  19-1013
# 3     01.0000  Agriculture, General.  19-4012
# 4     01.0000  Agriculture, General.  25-1041
# ...       ...                    ...      ...
# 6092  99.9999               NO MATCH  55-2012
# 6093  99.9999               NO MATCH  55-2013
# 6094  99.9999               NO MATCH  55-3011
# 6095  99.9999               NO MATCH  55-3013
# 6096  99.9999               NO MATCH  55-3016
#
#                                               soc_title
# 0                                     Animal Scientists
# 1                     Food Scientists and Technologists
# 2                             Soil and Plant Scientists
# 3                              Agricultural Technicians
# 4         Agricultural Sciences Teachers, Postsecondary
# ...                                                 ...
# 6092  First-Line Supervisors of Weapons Specialists/...
# 6093  First-Line Supervisors of All Other Tactical O...
# 6094                                   Air Crew Members
# 6095               Armored Assault Vehicle Crew Members
# 6096                                           Infantry
#
# [6097 rows x 4 columns]
